# %% [markdown]
# # Proyek Analisis Data: E-Commerce Public Dataset
# - **Nama:** Aqila Shafa Fazira
# - **Email:** l200220264@student.ums.ac.id
# - **ID Dicoding:**aqilashafa

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# 1. Bagaimana grafik penjualan di setiap bulanya?
# 2. Diantara produk yang ada, yang manakah yang paling tertinggi dan yang paling rendah terjual
# 3. Bagaimana jumlah pelanggan berdasar state dan kota

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import urllib

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# Data yang akan digunakan adalah geolocation, orders, order items, order reviews, customer, order payments, product, sellers, dan product category

# %%
geolocation = pd.read_csv("geolocation_dataset.csv")
print(geolocation.head())
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
customers = pd.read_csv("customers_dataset.csv")
print(customers.head())
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
order_items = pd.read_csv("order_items_dataset.csv")
print(order_items.head())
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
order_payment = pd.read_csv("order_payments_dataset.csv")
print(order_payment.head())
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
order_review = pd.read_csv("order_reviews_dataset.csv")
print(order_review.head())
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %%
orders = pd.read_csv("orders_dataset.csv")
print(orders.head())
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
product_category = pd.read_csv("product_category_name_translation.csv")
print(product_category.head())
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
products = pd.read_csv("products_dataset.csv")
print(products.head())
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
sellers = pd.read_csv("sellers_dataset.csv")
print(sellers.head())
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %% [markdown]
# #### Assessing Data

# %% [markdown]
# ###  Memeriksa data type setiap DataFrame

# %%
print(geolocation.info(), "\n")
print(customers.info(), "\n")
print(order_items.info(), "\n")
print(order_payment.info(), "\n")
print(order_review.info(), "\n")
print(orders.info(), "\n")
print(product_category.info(), "\n")
print(products.info(), "\n")
print(sellers.info(), "\n")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  object
#  4   geolocation_state            1000163 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 38.2+ MB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
# ...

# %% [markdown]
# Terdapat kesalahan data type pada DataFrame orders pada kolom order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, order_delivered_customer_date, dan orderr_estimated_delivery_date yang seharusnya memiliki data type datetime tetapi di DataFrame data type nya object. Kesalahan yang sama di DataFrame order_items di kolom shipping_limit_date dan pada DataFrame order_reviews di kolom review_creation_date. Data yang tidak sesuai akan diperbaiki di data clenaing

# %% [markdown]
# ### Memeriksa data null pada setiap DataFrame

# %%
print("Data null pada geolocation: \n", geolocation.isna().sum(), "\n")
print("Data null pada customers: \n", customers.isna().sum(), "\n")
print("Data null pada order_items: \n", order_items.isna().sum(), "\n")
print("Data null pada order_payment: \n", order_payment.isna().sum(), "\n")
print("Data null pada order_review: \n", order_review.isna().sum(), "\n")
print("Data null pada orders: \n", orders.isna().sum(), "\n")
print("Data null pada product_category: \n", product_category.isna().sum(), "\n")
print("Data null pada products: \n", products.isna().sum(), "\n")
print("Data null pada sellers: \n", sellers.isna().sum(), "\n")
# Out:
# Data null pada geolocation:
#  geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64
#
# Data null pada customers:
#  customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64
#
# Data null pada order_items:
#  order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64
#
# Data null pada order_payment:
#  order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64
#
# Data null pada order_review:
#  review_id                      0
# order_id                       0
# review_score                   0
# ...

# %% [markdown]
# Terdapat data null pada DataFrame orders di kolom order_approved_at, order_delivered_carrier_date, dan order_delivered_customer_date. Pada DataFrame order_reviews terdapat data null pada kolom review_comment_title dan review_comment_message. Pada DataFrame products terdapat data null pada kolom product_category_name, product_name_length, product_description_legnth, product_phots_qt, product_weight_g, product_length_cm, product_height_cm, dan product_width_cm

# %% [markdown]
# ### Memeriksa data duplicate pada setiap DataFrame

# %%
print("Jumlah duplikat pada geolocation: ", geolocation.duplicated().sum(), "\n")
print("Jumlah duplikat pada customers: ", customers.duplicated().sum(), "\n")
print("Jumlah duplikat pada order_items: ", order_items.duplicated().sum(), "\n")
print("Jumlah duplikat pada order_payment: ", order_payment.duplicated().sum(), "\n")
print("Jumlah duplikat pada order_review: ", order_review.duplicated().sum(), "\n")
print("Jumlah duplikat pada orders: ", orders.duplicated().sum(), "\n")
print("Jumlah duplikat pada product_category: ", product_category.duplicated().sum(), "\n")
print("Jumlah duplikat pada products: ", products.duplicated().sum(), "\n")
print("Jumlah duplikat pada sellers: ", sellers.duplicated().sum(), "\n")
# Out:
# Jumlah duplikat pada geolocation:  261831
#
# Jumlah duplikat pada customers:  0
#
# Jumlah duplikat pada order_items:  0
#
# Jumlah duplikat pada order_payment:  0
#
# Jumlah duplikat pada order_review:  0
#
# Jumlah duplikat pada orders:  0
#
# Jumlah duplikat pada product_category:  0
#
# Jumlah duplikat pada products:  0
#
# Jumlah duplikat pada sellers:  0

# %% [markdown]
# Pada dataset geolocation terdapat duplikat, sehingga harus dilakukan drop duplikat pada tahap data cleaning

# %% [markdown]
# ### Describe semua DataFrame

# %%
print("Data describe pada geolocation: \n", geolocation.describe(include="all"), "\n")
print("Data describe pada customers: \n", customers.describe(include="all"), "\n")
print("Data describe pada order_items: \n", order_items.describe(include="all"), "\n")
print("Data describe pada order_payment: \n", order_payment.describe(include="all"), "\n")
print("Data describe pada order_review: \n", order_review.describe(include="all"), "\n")
print("Data describe pada orders: \n", orders.describe(include="all"), "\n")
print("Data describe pada product_category: \n", product_category.describe(include="all"), "\n")
print("Data describe pada products: \n", products.describe(include="all"), "\n")
print("Data describe pada sellers: \n", sellers.describe(include="all"), "\n")
# Out:
# Data describe pada geolocation:
#          geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# count                  1.000163e+06     1.000163e+06     1.000163e+06
# unique                          NaN              NaN              NaN
# top                             NaN              NaN              NaN
# freq                            NaN              NaN              NaN
# mean                   3.657417e+04    -2.117615e+01    -4.639054e+01
# std                    3.054934e+04     5.715866e+00     4.269748e+00
# min                    1.001000e+03    -3.660537e+01    -1.014668e+02
# 25%                    1.107500e+04    -2.360355e+01    -4.857317e+01
# 50%                    2.653000e+04    -2.291938e+01    -4.663788e+01
# 75%                    6.350400e+04    -1.997962e+01    -4.376771e+01
# max                    9.999000e+04     4.506593e+01     1.211054e+02
#
#        geolocation_city geolocation_state
# count           1000163           1000163
# ...

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# ### Membersihkan dataset geolocation

# %% [markdown]
# Karena dataset geolocation memiliki data duplikat maka akan dilakukan drop duplicate

# %%
# Menghilangkan duplikat
geolocation.drop_duplicates(inplace=True)
print("Jumlah duplikat pada geolocation: ", geolocation.duplicated().sum())
# Out:
# Jumlah duplikat pada geolocation:  0

# %% [markdown]
# ### Membersihkan dataset orders

# %% [markdown]
# Dataset orders merupakan datset yang paling penting, karena didalamnya berisi data penting tentang kegiatam e-commerce. Pada analisis data kali ini, data yang akan digunakan hanya data orders yang sudah dikirimkan

# %%
# Melihat jumlah order berdasar orer_status
print(orders["order_status"].value_counts())
# Out:
# order_status
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: count, dtype: int64

# %%
# Menghitung jumlah data jika data yang diambil hanya data  delivered saja
delivered_percentage = (orders["order_status"].value_counts()["delivered"] / len(orders)) * 100
print("Jika hanya data delivered yang diambil, data yang diperoleh sebanyak " + str(round(delivered_percentage, 2)) + "% of data")
# Out:
# Jika hanya data delivered yang diambil, data yang diperoleh sebanyak 97.02% of data

# %% [markdown]
# Data yang diperoleh sebanyak 97.02% yang merupakan jumlah yang masih besar. Sehingga data orders yang akan digunakan untuk analisis lebih lanjut adalah data orders "delivered". Data lain akan di drop

# %%
# Menghapus data yang belum atau yang tidak terkirim
delivered_orders = orders.drop(orders[orders['order_status'] != 'delivered'].index)
orders = delivered_orders
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %% [markdown]
# Memeriksa kembai missing value dataset orders

# %%
orders.isna().sum()
# Out:
# order_id                          0
# customer_id                       0
# order_status                      0
# order_purchase_timestamp          0
# order_approved_at                14
# order_delivered_carrier_date      2
# order_delivered_customer_date     8
# order_estimated_delivery_date     0
# dtype: int64

# %% [markdown]
# Dapat disimpulkan bahwa kolom order_approved_at dan order_delivered_carrier_date tidak terlalu berpengaruh pada pertanyaan yang sudah diajukan. Akan tetapi terdapat 8 data yang null pada kolom order_delivered_customer_date yang berisi data tanggal dimana order diterima oleh customer. Data tersebut akan di drop

# %%
# Drop data null pada order_approved_at, order_delivered_carrier_date dan order_delivered_customer_date
orders = orders.dropna(subset=["order_approved_at", "order_delivered_carrier_date", "order_delivered_customer_date"])
orders.isna().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# dtype: int64

# %% [markdown]
# Menambahkan satu kolom untuk melihat order tepat waktu atau tidak. Tapi sebelum itu, harus mengubah data type yang masih berupa object

# %%
datetime_columns = ["order_purchase_timestamp", "order_approved_at", "order_delivered_carrier_date", "order_delivered_customer_date", "order_estimated_delivery_date"]
for column in datetime_columns:
  orders[column] = pd.to_datetime(orders[column])
orders.info()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24000\3833379967.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   orders[column] = pd.to_datetime(orders[column])
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24000\3833379967.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   orders[column] = pd.to_datetime(orders[column])
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24000\3833379967.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
orders["delivered_on_time"] = np.where(orders["order_delivered_customer_date"] <= orders["order_estimated_delivery_date"], "On Time", "Late")
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24000\3664303504.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   orders["delivered_on_time"] = np.where(orders["order_delivered_customer_date"] <= orders["order_estimated_delivery_date"], "On Time", "Late")

# %%
orders.sample(5)
# Out:
#                                order_id                       customer_id  \
# 25277  f6e638ae1f17003aac1cb6dc6a93ba73  bdeb52f66b5546ea418a547dc8888da5
# 18774  a17af8e6044c5ccaa87b1d97559dc554  8df8172ff39578fa8f41cccb8d28d9e7
# 83695  e0ee14b660378f233bb2e93a868cffb6  55c883877ae7ffd119c0661e7413818b
# 90142  1d21d12aea4b6b1a7debf1e5e5604734  0120ff9de7b5aba7cd8676c093f189de
# 53627  f1ec04b3b8679de55776bea7e3ad436f  2d9244f63bf21b376f8919c1f29faedc
#
#       order_status order_purchase_timestamp   order_approved_at  \
# 25277    delivered      2017-11-16 15:45:23 2017-11-16 16:09:28
# 18774    delivered      2018-02-16 17:59:44 2018-02-16 18:05:31
# 83695    delivered      2018-02-08 13:08:27 2018-02-08 13:29:26
# 90142    delivered      2018-01-25 15:50:30 2018-01-25 16:18:13
# 53627    delivered      2018-05-25 18:31:39 2018-05-25 18:58:34
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 25277          2017-11-17 19:58:46           2017-11-30 21:17:57
# ...

# %% [markdown]
# ### Membersihkan dataset order items

# %% [markdown]
# Ada kesalahan data ttype pada dataset order items. Data type kolom shipping_limit_date akan diubah yang sebelumnya object menjadi datetime

# %%
datetime_columns = ["shipping_limit_date"]
for column in datetime_columns:
  order_items[column] = pd.to_datetime(order_items[column])
order_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  datetime64[ns]
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 6.0+ MB

# %% [markdown]
# ### Membersihkan data order reviews

# %% [markdown]
# Klom review_comment_title dan review_comment_message masih terapat data null

# %%
# Melihat msiing value di review_comment_title
order_review[order_review.review_comment_title.isna()]
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# ...

# %% [markdown]
# Jumlah data null di review_comment_message akan diisi dengann "no comment"

# %%
# Menghapus kolom review_comment_title
order_review.drop("review_comment_title", axis=1, inplace=True)

# %% [markdown]
# Untuk data null di review_comment_message akan diisi dengan "no comment"

# %%
# Melihat missing value di review_comment_message
order_review[order_review.review_comment_message.isna()]
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 5      15197aa66ff4d0650b5434f1b46cda19  b18dcdf73be66366873cd26c5724d1dc
# 6      07f9bee5d1b850860defd761afa7ff16  e48aa0d2dcec3a2e87348811bcfdf22b
# ...                                 ...                               ...
# 99217  c6b270c61f67c9f7cb07d84ea8aeaf8b  48f7ee67313eda32bfcf5b9c1dd9522d
# 99218  af2dc0519de6e0720ef0c74292fb4114  d699c734a0b1c8111f2272a3f36d398c
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
#
#        review_score review_comment_message review_creation_date  \
# ...

# %%
order_review["review_comment_message"].fillna("No Comment", inplace=True)
print("Data null pada order reviews: \n", order_review.isna().sum())
# Out:
# Data null pada order reviews:
#  review_id                  0
# order_id                   0
# review_score               0
# review_comment_message     0
# review_creation_date       0
# review_answer_timestamp    0
# dtype: int64

# %% [markdown]
# Ada kesalahan data type. Data type di kolom review_creation_date akan diubah dari yang sebelumnya object menjadi datatime

# %%
datetime_columns = ["review_creation_date"]
for column in datetime_columns:
  order_review[column] = pd.to_datetime(order_review[column])
order_review.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_message   99224 non-null  object
#  4   review_creation_date     99224 non-null  datetime64[ns]
#  5   review_answer_timestamp  99224 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(4)
# memory usage: 4.5+ MB

# %% [markdown]
# ### Membersihkan dataset products

# %% [markdown]
# Untuk kolom product_weight_g, product_legth_cm, product_height_cm, product_width_cm terdapat masing-masing 2 data yang null. Data ini akan dihapus atau di drop. Kolom product_name_length dan product_descriptionn_length akan dihapus karena tidak terlalu digunakan untuk menjawab pertanyyan bisnia

# %%
products.dropna(subset=["product_name_lenght", "product_description_lenght", "product_height_cm", "product_width_cm"], inplace=True)

# %% [markdown]
# Untuk data null di kolom product_category_name akan diisi oleh value others

# %%
products["product_category_name"] = products["product_category_name"].fillna(value="other")

# %%
products["product_photos_qty"] = products["product_photos_qty"].fillna(value=0)

# %%
# Memeriksa kembali data null di products
products.isna().sum()
# Out:
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              0
# product_length_cm             0
# product_height_cm             0
# product_width_cm              0
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore geolocation

# %%
geolocation.sample(5)
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 143471                         5774       -23.635335       -46.750181
# 931680                        89500       -26.764071       -51.017798
# 848104                        80730       -25.429590       -49.290393
# 832713                        79094       -20.511835       -54.660560
# 591098                        35300       -19.789056       -42.146731
#
#        geolocation_city geolocation_state
# 143471        sao paulo                SP
# 931680          cacador                SC
# 848104         curitiba                PR
# 832713     campo grande                MS
# 591098        caratinga                MG

# %%
# Mengelompokkan geolocation berdasar geolocation zio code prefix
geolocation.groupby(by="geolocation_zip_code_prefix").size().sort_values(ascending=False)
# Out:
# geolocation_zip_code_prefix
# 38400    779
# 35500    751
# 11680    727
# 11740    678
# 36400    627
#         ...
# 85571      1
# 85579      1
# 4479       1
# 85138      1
# 84608      1
# Length: 19015, dtype: int64

# %% [markdown]
# ### Explore orders

# %%
orders.sample(5)
# Out:
#                                order_id                       customer_id  \
# 61219  c405c0976781fec4b0a89f6815abbc15  b25160fb0acdfdc69ae0c7fc1adbcda5
# 44825  d58bf4dd85230e05725202c1f0b4b800  a3c7076d6da760182e7c8991d96e7b53
# 88597  ae9c433acd3649acfb7c7bf169b307da  f315a90272ed1b6613938fbf58f0c329
# 70376  d2583409621fd344d75d3a27da727c40  ccc9f4665a052c90def8b7604384c6f2
# 47947  8e2f6e8aa36fa3770c9f33a7129e81a7  70d21c84f9843a2413b5921d5fb12add
#
#       order_status order_purchase_timestamp   order_approved_at  \
# 61219    delivered      2018-01-29 17:16:45 2018-01-29 17:35:35
# 44825    delivered      2017-07-25 21:44:16 2017-07-25 21:55:19
# 88597    delivered      2018-05-01 19:24:10 2018-05-01 19:35:26
# 70376    delivered      2018-02-06 09:16:11 2018-02-06 09:30:21
# 47947    delivered      2018-01-02 16:08:11 2018-01-04 05:14:03
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 61219          2018-01-30 23:06:21           2018-02-02 13:59:01
# ...

# %%
# Melihat jumlah data order yang dikirim tepat waktu dan yang telat
orders["delivered_on_time"]. value_counts()
# Out:
# delivered_on_time
# On Time    88630
# Late        7825
# Name: count, dtype: int64

# %% [markdown]
# ### Explore customers

# %%
customers.sample(5)
# Out:
#                             customer_id                customer_unique_id  \
# 97255  641cbccce28ca2f8b8482667f1dff4f4  1c54b236f385dc54ef0214afa0d77ad7
# 67015  b4540c2dc69a6c13c4e5d921a1d3c0af  b25d1e7fe5bd10c28191ec8b2b6d374b
# 35062  f56a6a5c5852ba57ea52152a4002e051  43098516e4db2a2b193bbccc0086b3f5
# 3841   a4747f37f033452617ad330896f582c6  9a5f4a671f4a0f580f0631021befd2f1
# 15696  4c5fddd41ec35898a6476a8048079ced  dd7aad249fd4f7cf7f1dc1d42cd1b48d
#
#        customer_zip_code_prefix customer_city customer_state
# 97255                     13478     americana             SP
# 67015                     90050  porto alegre             RS
# 35062                     70673      brasilia             DF
# 3841                       3568     sao paulo             SP
# 15696                      6657       itapevi             SP

# %%
customers.describe(include="all")
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     274fa6071e5e17fe303b9748641082c8  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# ...

# %%
#Melihat demografi pelanggan berdasar customer city
customers.groupby(by="customer_city").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_city
# sao paulo             15540
# rio de janeiro         6882
# belo horizonte         2773
# brasilia               2131
# curitiba               1521
#                       ...
# ponto novo                1
# populina                  1
# porteiras                 1
# portela                   1
# pitanga de estrada        1
# Name: customer_id, Length: 4119, dtype: int64

# %%
# Melihat demografi pelanggan berdasar customer state
customers.groupby(by="customer_state").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# PE     1652
# CE     1336
# PA      975
# MT      907
# MA      747
# MS      715
# PB      536
# PI      495
# RN      485
# AL      413
# SE      350
# TO      280
# RO      253
# AM      148
# AC       81
# AP       68
# RR       46
# Name: customer_id, dtype: int64

# %% [markdown]
# ### Explore orders payment

# %%
order_payment.sample(5)
# Out:
#                                order_id  payment_sequential payment_type  \
# 50263  d21d7411b251f35ead1b210dc946ca70                   2      voucher
# 99344  9f73f9300dc3e9f8efc83f19da546881                   1  credit_card
# 80611  86af1e4b328bff98d4fc63ca4ce8e94f                   1  credit_card
# 31085  a2fb9f237dfb7fb67d835e6507514943                   1       boleto
# 29925  0eb6c6aa0923d0a671134710c31319f7                   1  credit_card
#
#        payment_installments  payment_value
# 50263                     1          50.00
# 99344                     1          34.86
# 80611                     4         200.35
# 31085                     1         230.60
# 29925                     2         132.83

# %%
order_payment.groupby(by="payment_type").order_id.nunique().sort_values(ascending=False)
# Out:
# payment_type
# credit_card    76505
# boleto         19784
# voucher         3866
# debit_card      1528
# not_defined        3
# Name: order_id, dtype: int64

# %% [markdown]
# ### Explore orders dan customers

# %% [markdown]
# - Merge customers dan orders

# %%
customers_order = pd.merge(
    left=customers,
    right=orders,
    how="left",
    left_on="customer_id",
    right_on="customer_id"
)
customers_order.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %% [markdown]
# ### Explore order payments dan order reviews

# %% [markdown]
# - Merge order_payment dan order_review

# %%
pay_review = pd.merge(
    left=order_payment,
    right=order_review,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
pay_review.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
#
#    payment_installments  payment_value                         review_id  \
# 0                     8          99.33  4ce650e117a5b292bf5ea980a61eb61e
# 1                     1          24.39  ad2036caca61484fc435d7e673c020f2
# 2                     1          65.71  bcddfa0f7d2e54cfc74bae4f01b84d92
# 3                     8         107.78  c37a0e51e5df82bdb55d38ff0ffb6af3
# 4                     8         107.78  5bc7680443b4ef765fec11a8201eeb0c
#
#    review_score                             review_comment_message  \
# ...

# %%
# Mengurutkan order dengan biaya jumlah pembayaran paling tinggi
pay_review.sort_values(by="payment_value", ascending=False)
# Out:
#                                 order_id  payment_sequential payment_type  \
# 52415   03caa2c082116e1d31e67e9ae3700499                   1  credit_card
# 34565   736e1922ae60d0d6a89247b851902527                   1       boleto
# 41660   0812eb902a67711a1cb742b3cdaa65ae                   1  credit_card
# 49871   fefacc66af859508bf1a7934eab1e97f                   1       boleto
# 86018   f5136e38d1a14a4dbd87dff67da82701                   1       boleto
# ...                                  ...                 ...          ...
# 101330  b23878b3e8eb4d25a158f57d96331b18                   4      voucher
# 78326   fa65dad1b0e818e3ccc5cb0e39231352                  13      voucher
# 51581   4637ca194b6387e2d538dc89b124b0ee                   1  not_defined
# 44001   6ccb433e00daae1283ccc956189c82ae                   4      voucher
# 94953   c8c528189310eaa44a745b8d9d26908b                   1  not_defined
#
#         payment_installments  payment_value                         review_id  \
# ...

# %%
# Melihat demografi jenis pembayaran
pay_review.groupby(by="payment_type").agg({
    "order_id" : "nunique",
    "payment_value": ["min", "max"]
})
# Out:
#              order_id payment_value
#               nunique           min       max
# payment_type
# boleto          19784         11.62   7274.88
# credit_card     76505          0.01  13664.08
# debit_card       1528         13.38   4445.50
# not_defined         3          0.00      0.00
# voucher          3866          0.00   3184.34

# %% [markdown]
# - Merge customers_order dan pay_review

# %%
cust_pay = pd.merge(
    left=customers_order,
    right=pay_review,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
cust_pay.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %% [markdown]
# ### Explore order items dan sellers

# %% [markdown]
# - Merge order items dan sellers

# %%
order_sellers = pd.merge(
    left=order_items,
    right=sellers,
    how="left",
    left_on="seller_id",
    right_on="seller_id"
)
order_sellers.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value  seller_zip_code_prefix  \
# 0 2017-09-19 09:45:35   58.90          13.29                   27277
# 1 2017-05-03 11:05:13  239.90          19.93                    3471
# ...

# %%
# Melihat seller's city
order_sellers.groupby(by="seller_city").seller_id.nunique().sort_values(ascending=False).head(10)
# Out:
# seller_city
# sao paulo         694
# curitiba          127
# rio de janeiro     96
# belo horizonte     68
# ribeirao preto     52
# guarulhos          50
# ibitinga           49
# santo andre        45
# campinas           41
# maringa            40
# Name: seller_id, dtype: int64

# %%
# Melihat seller's state
order_sellers.groupby(by="seller_state").seller_id.nunique().sort_values(ascending=False).head(10)
# Out:
# seller_state
# SP    1849
# PR     349
# MG     244
# SC     190
# RJ     171
# RS     129
# GO      40
# DF      30
# ES      23
# BA      19
# Name: seller_id, dtype: int64

# %% [markdown]
# ### Explore products dan product category name translation

# %% [markdown]
# - Merge product dan product category name translation

# %%
product_name = pd.merge(
    left=products,
    right=product_category,
    how="left",
    left_on="product_category_name",
    right_on="product_category_name"
)
product_name.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0             225.0               16.0               10.0              14.0
# ...

# %%
# Melihat pengelompokan produk berdasar product category name (sebelum diterjemahkan)
product_name.groupby(by="product_category_name").product_id.nunique().sort_values(ascending=False).head(10)
# Out:
# product_category_name
# cama_mesa_banho           3029
# esporte_lazer             2867
# moveis_decoracao          2657
# beleza_saude              2444
# utilidades_domesticas     2335
# automotivo                1900
# informatica_acessorios    1639
# brinquedos                1411
# relogios_presentes        1329
# telefonia                 1134
# Name: product_id, dtype: int64

# %%
# Melihat pengelompokan produk berdasar product category name (setelah diterjemahkan)
product_name.groupby(by="product_category_name_english").product_id.nunique().sort_values(ascending=False).head(10)
# Out:
# product_category_name_english
# bed_bath_table           3029
# sports_leisure           2867
# furniture_decor          2657
# health_beauty            2444
# housewares               2335
# auto                     1900
# computers_accessories    1639
# toys                     1411
# watches_gifts            1329
# telephony                1134
# Name: product_id, dtype: int64

# %% [markdown]
# - Merge order_sellers dan cust_pay

# %%
order_pay = pd.merge(
    left=product_name,
    right=order_sellers,
    how="left",
    left_on="product_id",
    right_on="product_id"
)
order_pay.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0             225.0               16.0               10.0              14.0
# ...

# %%
# Diurutkan berdasar harga tertinggi
order_pay.sort_values(by="price", ascending=False)
# Out:
#                              product_id              product_category_name  \
# 20259  489ae2aa008f021502940f251d4cce7f              utilidades_domesticas
# 72948  69c590f7ffc7bf8db97190b6cb6ed62e                                pcs
# 48843  1bdf5e6731585cf01aa8169c7028d6ad                              artes
# 70869  a6492cc69376c469ab6f61d8f44de961                    eletroportateis
# 31828  c3ed642d592594bb648ff4a04cee2747                    eletroportateis
# ...                                 ...                                ...
# 55172  05b515fdc76e888aada3c6d66c201dff                       beleza_saude
# 55176  05b515fdc76e888aada3c6d66c201dff                       beleza_saude
# 29223  8a3254bee785a526d548a81a9bc3c9be  construcao_ferramentas_construcao
# 29222  8a3254bee785a526d548a81a9bc3c9be  construcao_ferramentas_construcao
# 29221  8a3254bee785a526d548a81a9bc3c9be  construcao_ferramentas_construcao
#
# ...

# %%
#Melihat pengelompokan product category name yang sudah diterjemahkan
order_pay.groupby(by="product_category_name_english").agg({
    "order_id" : "nunique",
    "price": ["min", "max"]
})
# Out:
#                               order_id  price
#                                nunique    min      max
# product_category_name_english
# agro_industry_and_commerce         182  12.99  2990.00
# air_conditioning                   253  10.90  1599.00
# art                                202   3.50  6499.00
# arts_and_craftmanship               23   9.80   289.49
# audio                              350  14.90   598.99
# ...                                ...    ...      ...
# stationery                        2311   2.29  1693.00
# tablets_printing_image              79  14.90   889.99
# telephony                         4199   5.00  2428.00
# toys                              3886   4.90  1699.99
# watches_gifts                     5624   8.99  3999.90
#
# [71 rows x 3 columns]

# %% [markdown]
# ### Explore all data

# %% [markdown]
# Seluruh data di merge selain data geolocation karena tidak penting

# %%
all_data = pd.merge(
    left=cust_pay,
    right=order_pay,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
all_data.head(20)
# Out:
#                          customer_id                customer_unique_id  \
# 0   06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1   18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2   4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3   b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4   4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# 5   879864dab9bc3047522c92c82e1212b8  4c93744516667ad3b8f1fb645a3116a4
# 6   fd826e7cf63160e536e0908c76c3f441  addec96d2e059c80c30fe6871d30d177
# 7   5e274e7a0c3809e14aba7ad5aae0d407  57b2a98a409812fe9618067b6b8ebe4f
# 8   5adf08e34b2e993982a47070956c5c65  1175e95fb47ddff9de6b2b06188f7e0d
# 9   4b7139f34592b3a31687243a302fa75b  9afe194fb833f79e300e37e580171f22
# 10  9fb35e4ed6f0a14a4977cd9aea4042bb  2a7745e1ed516b289ed9b29c7d0539a5
# 11  5aa9e4fdd4dfd20959cad2d772509598  2a46fb94aef5cbeeb850418118cee090
# ...

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118467 entries, 0 to 118466
# Data columns (total 40 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   customer_id                    118467 non-null  object
#  1   customer_unique_id             118467 non-null  object
#  2   customer_zip_code_prefix       118467 non-null  int64
#  3   customer_city                  118467 non-null  object
#  4   customer_state                 118467 non-null  object
#  5   order_id                       115481 non-null  object
#  6   order_status                   115481 non-null  object
#  7   order_purchase_timestamp       115481 non-null  datetime64[ns]
#  8   order_approved_at              115481 non-null  datetime64[ns]
#  9   order_delivered_carrier_date   115481 non-null  datetime64[ns]
#  10  order_delivered_customer_date  115481 non-null  datetime64[ns]
# ...

# %%
# Menghilangkan duplikat
all_data.drop_duplicates(inplace=True)
all_data.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Melihat total pembelian berdasar state
all_data.groupby(by="customer_state").agg({
    "order_id" : "nunique",
    "payment_value": "sum"
}).sort_values(by="payment_value", ascending=False)
# Out:
#                 order_id  payment_value
# customer_state
# SP                 40488     7434677.68
# RJ                 12348     2694177.84
# MG                 11351     2287776.67
# RS                  5342     1108280.99
# PR                  4923     1034601.30
# BA                  3256      772423.42
# SC                  3546      768405.87
# GO                  1957      496426.61
# DF                  2080      424613.99
# ES                  1995      399201.58
# PE                  1593      361363.59
# CE                  1278      332168.11
# PA                   946      255327.31
# MT                   886      251859.09
# MA                   716      195191.60
# PB                   517      177320.00
# MS                   701      164556.97
# PI                   476      133729.03
# RN                   474      115203.08
# AL                   397      108727.76
# SE                   335       85694.32
# TO                   274       70780.74
# ...

# %%
# Melihat data jumlah min dan max pembelian produk
all_data.groupby(by="product_category_name_english").agg({
    "order_id" : "nunique",
    "review_score" : ["min", "max"]
})
# Out:
#                               order_id review_score
#                                nunique          min  max
# product_category_name_english
# agro_industry_and_commerce         177          1.0  5.0
# air_conditioning                   246          1.0  5.0
# art                                195          1.0  5.0
# arts_and_craftmanship               23          1.0  5.0
# audio                              348          1.0  5.0
# ...                                ...          ...  ...
# stationery                        2264          1.0  5.0
# tablets_printing_image              79          1.0  5.0
# telephony                         4092          1.0  5.0
# toys                              3803          1.0  5.0
# watches_gifts                     5493          1.0  5.0
#
# [71 rows x 3 columns]

# %% [markdown]
# ### Convert all_data ke .csv

# %%
all_data.to_csv("all_data.csv", index=False)

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Bagaimana grafik penjualan di setiap bulanya?

# %% [markdown]
# Perlu membuat DataFrame baru yang menampung informasi jumlah order dan total revene per bulan untuk menjawab pertanyaan ini. Sehingga frekuensi data yang awalnya harian harus diubah menjadi bulanan. Kemudian informasi tentang performa penjualan dan revenue akan divisualisasikan menggunakan line chart

# %%
monthly_orders = all_data.resample(rule='ME', on='order_approved_at').agg({
    "order_id": "nunique",
    "payment_value": "sum"
})
monthly_orders.index = monthly_orders.index.strftime('%B')
monthly_orders = monthly_orders.reset_index()
monthly_orders.rename(columns={
    "order_approved_at": "order_date",
    "order_id": "order_count",
    "payment_value": "revenue"
}, inplace=True)
monthly_orders
# Out:
#    order_date  order_count     revenue
# 0   September            1        0.00
# 1     October          265    62185.82
# 2    November            0        0.00
# 3    December            1       19.62
# 4     January          715   171054.49
# 5    February         1638   325381.93
# 6       March         2554   505582.49
# 7       April         2278   450650.20
# 8         May         3547   705181.88
# 9        June         3143   594915.16
# 10       July         3828   710030.63
# 11     August         4217   849996.67
# 12  September         4169   897290.35
# 13    October         4441  1096194.24
# 14   November         7149  1536858.63
# 15   December         5675  1054699.20
# 16    January         6991  1357598.89
# 17   February         6536  1280434.93
# 18      March         7083  1452494.81
# 19      April         6639  1443732.48
# 20        May         6940  1513867.69
# 21       June         6094  1292834.76
# 22       July         6047  1281816.75
# ...

# %%
# Menghapus data duplikasi per bulan dan hanya mengambil data terakhir
monthly_orders=monthly_orders.sort_values("order_count").drop_duplicates("order_date", keep='last')

# %%
monthly_orders.sort_values(by="order_count", ascending=False)
# Out:
#    order_date  order_count     revenue
# 14   November         7149  1536858.63
# 18      March         7083  1452494.81
# 16    January         6991  1357598.89
# 20        May         6940  1513867.69
# 19      April         6639  1443732.48
# 17   February         6536  1280434.93
# 23     August         6504  1246443.51
# 21       June         6094  1292834.76
# 22       July         6047  1281816.75
# 15   December         5675  1054699.20
# 13    October         4441  1096194.24
# 12  September         4169   897290.35

# %%
months_order = ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"]
monthly_orders["order_date"] = pd.Categorical(monthly_orders["order_date"], categories=months_order, ordered=True)
monthly_orders = monthly_orders.sort_values("order_date")

plt.figure(figsize=(15,7))
plt.plot(monthly_orders["order_date"], monthly_orders["order_count"], marker="o", linewidth=4)
plt.title("Jumlah Pesanan per Bulan (2018)", loc="center", fontsize=14)
plt.xlabel("Month", fontsize=12)
plt.ylabel("Jumlah Pesanan", fontsize=12)
plt.xticks(rotation=45, fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %% [markdown]
# Terdapat penurunan signifikan pada bulan Agustus dan terjadi kenaikan Oktober

# %% [markdown]
# ### Pertanyaan 2: Diantara produk yang ada, yang manakah yang paling tertinggi dan yang paling rendah terjual?

# %% [markdown]
# Membuat DataFrame baru yang berisikan data produk dan kuantitas. Lalu informasi jumlah produk terjual akan divisualisasikan dengan bar chart

# %%
sum_order_items = all_data.groupby("product_category_name_english")["product_id"].count().reset_index()
sum_order_items = sum_order_items.rename(columns={"product_id": "products"})
sum_order_items = sum_order_items.sort_values(by="products", ascending=False)
sum_order_items
# Out:
#    product_category_name_english  products
# 7                 bed_bath_table     11813
# 43                 health_beauty      9816
# 65                sports_leisure      8788
# 39               furniture_decor      8639
# 15         computers_accessories      7962
# ..                           ...       ...
# 3          arts_and_craftmanship        24
# 52                    la_cuisine        16
# 11             cds_dvds_musicals        14
# 29     fashion_childrens_clothes         7
# 61         security_and_services         2
#
# [71 rows x 2 columns]

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24, 6))

colors = ["#068DA9", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]

sns.barplot(x="products", y="product_category_name_english", data=sum_order_items.head(5), palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("Produk paling banyak terjual", loc="center", fontsize=18)
ax[0].tick_params(axis ='y', labelsize=15)

sns.barplot(x="products", y="product_category_name_english", data=sum_order_items.sort_values(by="products", ascending=True).head(5), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].invert_xaxis()
ax[1].yaxis.set_label_position("right")
ax[1].yaxis.tick_right()
ax[1].set_title("Produk paling sedikit terjual", loc="center", fontsize=18)
ax[1].tick_params(axis='y', labelsize=15)

plt.suptitle("Produk paling banyak dan paling sedikit terjual", fontsize=20)
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24000\1116653299.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="products", y="product_category_name_english", data=sum_order_items.head(5), palette=colors, ax=ax[0])
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24000\1116653299.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="products", y="product_category_name_english", data=sum_order_items.sort_values(by="products", ascending=True).head(5), palette=colors, ax=ax[1])

# %% [markdown]
# Dari bar chart diatas terlihat bahwa produk yang paling banyak terjual adalah bed_bath_table dan produk paling sedikit terjual adalah security_and_services

# %% [markdown]
# ### Pertanyaan 3: Bagaimana jumlah pelanggan berdasar kota dan state?

# %% [markdown]
# - Demografi pelanggan berdasar kota

# %%
bycity = all_data['customer_city'].value_counts().head(10)

plt.figure(figsize=(12, 6))

most_common_city = bycity.idxmax()

bycity = bycity.sort_values(ascending=False)

sns.barplot(x=bycity.index,
            y=bycity.values,
            palette=["#068DA9" if city == most_common_city else "#D3D3D3" for city in bycity.index]
            )

plt.title("Jumlah Pelanggan Berdasarkan Kota", fontsize=15)
plt.xlabel("Kota")
plt.ylabel("Jumlah Pelanggan")
plt.xticks(rotation=45, fontsize=10)
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24000\3765666439.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=bycity.index,

# %% [markdown]
# - Demografi berdasar state

# %%
bystate = all_data['customer_state'].value_counts().head(10)

plt.figure(figsize=(12, 6))

most_common_city = bystate.idxmax()

bystate = bystate.sort_values(ascending=False)

sns.barplot(x=bystate.index,
            y=bystate.values,
            palette=["#068DA9" if city == most_common_city else "#D3D3D3" for city in bystate.index]
            )

plt.title("Jumlah Pelanggan Berdasarkan State", fontsize=15)
plt.xlabel("State")
plt.ylabel("Jumlah Pelanggan")
plt.xticks(rotation=45, fontsize=10)
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24000\3120609460.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=bystate.index,

# %% [markdown]
# ## Conclusion

# %% [markdown]
# 1. Setiap bulanya produk mengalami kenaikan dan penurunan yang masih wajar. Namun, pada bulan Agustus produk mengalami penurunan yang signifikan dan mulai Kembali naik pada bulan September, dimana bulan October mulai mengalami kenaikan yang signifikan
# 2. Berdasar bar chart yang dihasilkan produk yang paling tinggi penjualanya adalah produk bed_bath_table dan produk dengan penjualan paling sedikit terjual adalah security_and_services
# 3. Jumlah pelanggan di kota yang paling banyak terdapat di kota sao paulo dan jumlah pelanggan di state yang paling sedikit adalah sp
